# %% [markdown]
# <a href="https://colab.research.google.com/github/talisma-cassoma/HAND-GESTURES-DRIVE-CAR/blob/main/trainning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# instalar a api do roboflow

# %%
# !pip install roboflow
# Out:
# ...
#      |████████████████████████████████| 145 kB 5.3 MB/s
# ...
#      |████████████████████████████████| 178 kB 42.0 MB/s
# ...
#      |████████████████████████████████| 1.1 MB 45.9 MB/s
# ...
#      |████████████████████████████████| 67 kB 5.7 MB/s
# ...
#      |████████████████████████████████| 54 kB 2.8 MB/s
# ...
#      |████████████████████████████████| 138 kB 45.4 MB/s
# ...
#      |████████████████████████████████| 596 kB 30.6 MB/s
# ...
#      |████████████████████████████████| 63 kB 1.6 MB/s
# ...
#   Created wheel for roboflow: filename=roboflow-0.2.4-py3-none-any.whl size=21356 sha256=a1908d0c7b04851a83f3d19107411e804f33ee111ab9ddd54d586ff8bb7e94ac
#   Stored in directory: /root/.cache/pip/wheels/b7/2c/60/3733c0e323b1d7aec00f852264314bf6c48192c8e1dc92b3ee
# ...
#   Created wheel for wget: filename=wget-3.2-py3-none-any.whl size=9675 sha256=b873080dca5b28511f7e80745482d965aa223d9d18259f899665d4cb1a405378
#   Stored in directory: /root/.cache/pip/wheels/a1/b6/7c/0e63e34eb06634181c63adacca38b79ff8f35c37e3c13e3c02
# ...

# %% [markdown]
# pegar o dataset do roboflow

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="*******")
project = rf.workspace("talisma").project("handgesture-w073v")
dataset = project.version(3).download("yolov5")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to handGesture-3 in yolov5pytorch:: 100%|██████████| 2098/2098 [00:01<00:00, 1290.85it/s]

# %% [markdown]
# copiar o dataset para o meu drive

# %%
# !cp -a -v /content/handGesture-3 /content/drive/MyDrive
# Out:
# '/content/handGesture-3' -> '/content/drive/MyDrive/handGesture-3'
# '/content/handGesture-3/README.dataset.txt' -> '/content/drive/MyDrive/handGesture-3/README.dataset.txt'
# '/content/handGesture-3/README.roboflow.txt' -> '/content/drive/MyDrive/handGesture-3/README.roboflow.txt'
# '/content/handGesture-3/data.yaml' -> '/content/drive/MyDrive/handGesture-3/data.yaml'
# '/content/handGesture-3/test' -> '/content/drive/MyDrive/handGesture-3/test'
# '/content/handGesture-3/test/images' -> '/content/drive/MyDrive/handGesture-3/test/images'
# '/content/handGesture-3/test/images/107_jpg.rf.3a249fee14879f1e855675a8f91a4829.jpg' -> '/content/drive/MyDrive/handGesture-3/test/images/107_jpg.rf.3a249fee14879f1e855675a8f91a4829.jpg'
# '/content/handGesture-3/test/images/10_jpg.rf.4dfe1e21f0651a58e8ef166bbd63d4d2.jpg' -> '/content/drive/MyDrive/handGesture-3/test/images/10_jpg.rf.4dfe1e21f0651a58e8ef166bbd63d4d2.jpg'
# ...

# %% [markdown]
# clonar o repo do yolov5( nossa rede neural em tempo real )

# %%
# !git clone https://github.com/ultralytics/yolov5
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 13006, done.
# remote: Total 13006 (delta 0), reused 0 (delta 0), pack-reused 13006
# Receiving objects: 100% (13006/13006), 11.93 MiB | 27.89 MiB/s, done.
# Resolving deltas: 100% (9037/9037), done.

# %% [markdown]
# mover para o dir do projeto

# %%
# !cp -a -v /content/drive/MyDrive/yolov5  /content/drive/MyDrive/handGesture-3
# Out:
# '/content/drive/MyDrive/yolov5' -> '/content/drive/MyDrive/handGesture-3/yolov5'
# '/content/drive/MyDrive/yolov5/requirements.txt' -> '/content/drive/MyDrive/handGesture-3/yolov5/requirements.txt'
# '/content/drive/MyDrive/yolov5/LICENSE' -> '/content/drive/MyDrive/handGesture-3/yolov5/LICENSE'
# '/content/drive/MyDrive/yolov5/.gitignore' -> '/content/drive/MyDrive/handGesture-3/yolov5/.gitignore'
# '/content/drive/MyDrive/yolov5/val.py' -> '/content/drive/MyDrive/handGesture-3/yolov5/val.py'
# '/content/drive/MyDrive/yolov5/.pre-commit-config.yaml' -> '/content/drive/MyDrive/handGesture-3/yolov5/.pre-commit-config.yaml'
# '/content/drive/MyDrive/yolov5/export.py' -> '/content/drive/MyDrive/handGesture-3/yolov5/export.py'
# '/content/drive/MyDrive/yolov5/hubconf.py' -> '/content/drive/MyDrive/handGesture-3/yolov5/hubconf.py'
# '/content/drive/MyDrive/yolov5/README.md' -> '/content/drive/MyDrive/handGesture-3/yolov5/README.md'
# ...

# %% [markdown]
# verificar se gpu foi ativada e mover para o dir yolov5

# %%
# !nvidia-smi
# Out:
# Thu Apr 28 16:31:22 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla K80           Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   36C    P8    27W / 149W |      0MiB / 11441MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %% [markdown]
# instalar as dependencia do projeto

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %ls
# Out:
# drive/  sample_data/

# %%
# !pip install -U -r /content/drive/MyDrive/handGesture-3/yolov5/requirements.txt
# Out:
# ...
#      |████████████████████████████████| 11.2 MB 5.3 MB/s
# ...
#      |████████████████████████████████| 60.5 MB 1.4 MB/s
# ...
#      |████████████████████████████████| 4.3 MB 35.9 MB/s
# ...
#      |████████████████████████████████| 63 kB 1.6 MB/s
# ...
#      |████████████████████████████████| 38.1 MB 1.3 MB/s
# ...
#      |████████████████████████████████| 930 kB 39.0 MB/s
# ...
#   Attempting uninstall: requests
#     Found existing installation: requests 2.23.0
#     Uninstalling requests-2.23.0:
#       Successfully uninstalled requests-2.23.0
#   Attempting uninstall: Pillow
#     Found existing installation: Pillow 7.1.2
#     Uninstalling Pillow-7.1.2:
#       Successfully uninstalled Pillow-7.1.2
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.4.1
#     Uninstalling scipy-1.4.1:
#       Successfully uninstalled scipy-1.4.1
#   Attempting uninstall: matplotlib
#     Found existing installation: matplotlib 3.2.2
#     Uninstalling matplotlib-3.2.2:
# ...

# %%
# !python /content/drive/MyDrive/handGesture-3/yolov5/train.py --img 416 --batch 16 --epochs 500 --data /content/drive/MyDrive/handGesture-3/data.yaml --cfg /content/drive/MyDrive/handGesture-3/yolov5/models/yolov5s.yaml --weights /content/drive/MyDrive/handGesture-3 --name yolov5s_results  --cache --device 0
# Out:
# train: weights=/content/drive/MyDrive/handGesture-3, cfg=/content/drive/MyDrive/handGesture-3/yolov5/models/yolov5s.yaml, data=/content/drive/MyDrive/handGesture-3/data.yaml, hyp=drive/MyDrive/handGesture-3/yolov5/data/hyps/hyp.scratch-low.yaml, epochs=500, batch_size=16, imgsz=416, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=ram, image_weights=False, device=0, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=drive/MyDrive/handGesture-3/yolov5/runs/train, name=yolov5s_results, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# Command 'git fetch && git config --get remote.origin.url' timed out after 5 seconds
# YOLOv5 🚀 v6.1-162-g2611477 torch 1.11.0+cu113 CUDA:0 (Tesla K80, 11441MiB)
#
# ...
